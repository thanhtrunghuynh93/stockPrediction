# %%
import numpy as np
import pandas as pd
import os
from matplotlib.pyplot import title
import requests
import json
import pandas as pd
import mplfinance as mpl
from stockstats import StockDataFrame as Sdf
import math

from utils.date_util import *

# %%
data_src = "data/Vietnam"
stock_list = np.load(data_src + "/list_stocks.npy", allow_pickle = True)
stock_infos = pd.read_csv("data/Vietnam/stock_infos.csv", index_col = "ticker")
basicFA = pd.read_csv("data/Vietnam/basic_FA.csv", index_col = "ticker")
trailing_quarter = pd.read_csv("data/Vietnam/trailing_quarter_report.csv", index_col = "ticker")
trailing_year = pd.read_csv("data/Vietnam/trailing_year_report.csv", index_col = "ticker")
quarters, years = get_last_quarters("Q4/2022", num_periods = 35)

stock_list = list(trailing_quarter.index.unique())

# %%
quarters, years = get_last_quarters("Q4/2022", num_periods = 35)
needed_columns = ["Name", "Symbol"] + quarters

# df = getTrailingInfo(stock_list, stock_infos, authorization, needed_columns, period = "Q", limit = 34)
# df.to_csv("data/Vietnam/208_all_metadata/trailing_quarter_FA.csv")


years = years[0:-1]
needed_columns = ["Name", "Symbol"] + years

# df = getTrailingInfo(stock_list, stock_infos, authorization, needed_columns, period = "Y", limit = len(years))
# df = df.set_index("ticker")
# df.to_csv("data/Vietnam/208_all_metadata/trailing_year_FA.csv")

# %%
from utils.date_util import generate_quarters
from analysis.CANSLIM_analysis import CANSLIM_analysis

insight_quarters = generate_quarters(1, 2020, 1, 2023)

print(insight_quarters)
# print(trailing_year)
# Out:
# ['Q1/2020', 'Q2/2020', 'Q3/2020', 'Q4/2020', 'Q1/2021', 'Q2/2021', 'Q3/2021', 'Q4/2021', 'Q1/2022', 'Q2/2022', 'Q3/2022', 'Q4/2022', 'Q1/2023']

# %%
trailing_quarter
# Out:
#         Unnamed: 0  quarter  year  accountsPayable     bookValue  \
# ticker
# VCB              0        1  2014     1.427319e+13  4.130691e+14
# VCB              1        2  2014     4.845522e+12  4.643962e+14
# VCB              2        3  2014     9.228259e+12  4.696193e+14
# VCB              3        4  2014     6.567646e+12  5.071459e+14
# VCB              4        1  2015     6.022657e+12  5.138841e+14
# ...            ...      ...   ...              ...           ...
# VPH           6487        4  2021     1.211678e+12  1.869681e+12
# VPH           6488        1  2022     8.594190e+11  1.708713e+12
# VPH           6489        2  2022     9.488485e+11  1.726232e+12
# VPH           6490        3  2022     9.915298e+11  1.653802e+12
# VPH           6491        4  2022     1.222476e+12  1.718227e+12
#
#         capitalExpense  cashEquivalents  costOfFund  costToIncomeRatio  \
# ticker
# VCB       2.944620e+11     1.607526e+14        4.51              39.34
# VCB       2.498240e+11     2.041834e+14        3.99              40.06
# VCB       9.522620e+11     2.215847e+14        3.81              40.18
# VCB       7.676270e+11     2.415919e+14        3.41              39.52
# VCB       8.038010e+11     2.001122e+14        3.55              39.75
# ...                ...              ...         ...                ...
# VPH      -3.950037e+09     1.868667e+11         NaN                NaN
# VPH      -5.155510e+09     1.297664e+11         NaN                NaN
# VPH      -2.176371e+10     9.442421e+10         NaN                NaN
# VPH      -1.017021e+10     6.175873e+10         NaN                NaN
# VPH      -7.977425e+09     8.708845e+10         NaN                NaN
#
#         earningBeforeInterestTax  ...  longTermAssets  longTermDebtOnEquity  \
# ticker                            ...
# VCB                 5.436556e+12  ...             NaN                   NaN
# VCB                 5.467530e+12  ...             NaN                   NaN
# VCB                 5.441153e+12  ...             NaN                   NaN
# VCB                 5.743670e+12  ...             NaN                   NaN
# VCB                 5.345484e+12  ...             NaN                   NaN
# ...                          ...  ...             ...                   ...
# VPH                 3.218511e+10  ...    2.792184e+11                  0.08
# VPH                 1.088457e+10  ...    4.068579e+11                  0.00
# VPH                 1.212650e+10  ...    3.837862e+11                  0.00
# VPH                 2.371254e+10  ...    4.255501e+11                  0.00
# VPH                 9.522273e+09  ...    4.506224e+11                  0.00
#
#         longTermLiabilities  longTermReceivables  quickPaymentRatio  \
# ticker
# VCB                     NaN                  NaN                NaN
# VCB                     NaN                  NaN                NaN
# VCB                     NaN                  NaN                NaN
# VCB                     NaN                  NaN                NaN
# VCB                     NaN                  NaN                NaN
# ...                     ...                  ...                ...
# VPH            8.097516e+10         2.300746e+09               2.90
# VPH            0.000000e+00         2.300746e+09               3.80
# VPH            0.000000e+00         3.668746e+09               3.59
# VPH            0.000000e+00         3.668746e+09               3.19
# VPH            0.000000e+00         2.659951e+10               1.45
#
#         receivablesTurnover  returnOnEmployedCapital  returnOnInvestedCapital  \
# ticker
# VCB                     NaN                      NaN                      NaN
# VCB                     NaN                      NaN                      NaN
# VCB                     NaN                      NaN                      NaN
# VCB                     NaN                      NaN                      NaN
# VCB                     NaN                      NaN                      NaN
# ...                     ...                      ...                      ...
# VPH                   0.430                     4.19                     4.26
# VPH                   0.373                     4.24                     4.76
# VPH                   0.387                     4.36                     6.42
# VPH                   0.357                     4.89                     5.34
# VPH                   0.452                     4.82                     5.17
#
#         returnOnSales  shortTermDebtOnEquity
# ticker
# VCB               NaN                    NaN
# VCB               NaN                    NaN
# VCB               NaN                    NaN
# VCB               NaN                    NaN
# VCB               NaN                    NaN
# ...               ...                    ...
# VPH             30.97                   0.40
# VPH             36.72                   0.29
# VPH             40.64                   0.33
# VPH             37.93                   0.38
# VPH             40.40                   0.52
#
# [6492 rows x 62 columns]

# %%
for insight_quarter in insight_quarters:
    
    print(insight_quarter)
    analyzer = CANSLIM_analysis(stock_list, stock_infos, basicFA, trailing_quarter, trailing_year, insight_quarter)
    candidates = analyzer.filter(threshold = 10)
    np.save(data_src + "/CANSLIM/" + insight_quarter.replace("/", "_") + "_shortlist.npy", candidates)
    
    print(candidates)
# Out:
# Q1/2020
# Error of missing data for GVR in Q4/2019
# Error of missing data for THD in Q4/2019
# Error of missing data for OCB in Q4/2019
# Error of missing data for OIL in Q4/2019
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:166: RuntimeWarning: divide by zero encountered in double_scalars
#   revenue_growth_previous_quarter = trailing_quarter.loc[(stock, previous_quarter)]["sales"] / trailing_quarter.loc[(stock, last_previous_quarter)]["sales"] - 1
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:167: RuntimeWarning: invalid value encountered in double_scalars
#   revenue_growth_quarter_acceleration = (revenue_growth_current_quarter - revenue_growth_previous_quarter) / abs(revenue_growth_previous_quarter)
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:170: RuntimeWarning: divide by zero encountered in double_scalars
#   profit_growth_previous_quarter = trailing_quarter.loc[(stock, previous_quarter)]["netProfit"] / trailing_quarter.loc[(stock, last_previous_quarter)]["netProfit"] - 1
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:171: RuntimeWarning: invalid value encountered in double_scalars
#   profit_growth_quarter_acceleration = (profit_growth_current_quarter - profit_growth_previous_quarter) / abs(profit_growth_previous_quarter)
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:157: RuntimeWarning: divide by zero encountered in double_scalars
#   pp_previous_ROE = trailing_quarter.loc[(stock, pp_previous_quarter)]["netProfit"] / abs(trailing_quarter.loc[(stock, pp_previous_quarter)]["ownerEquity"]) * 100 * 4
# Error of missing data for ABB in Q4/2019
# Error of missing data for APH in Q4/2019
# Error of missing data for AGG in Q4/2019
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:155: RuntimeWarning: divide by zero encountered in double_scalars
#   previous_ROE = trailing_quarter.loc[(stock, previous_quarter)]["netProfit"] / abs(trailing_quarter.loc[(stock, previous_quarter)]["ownerEquity"]) * 100 * 4
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:156: RuntimeWarning: divide by zero encountered in double_scalars
#   p_previous_ROE = trailing_quarter.loc[(stock, p_previous_quarter)]["netProfit"] / abs(trailing_quarter.loc[(stock, p_previous_quarter)]["ownerEquity"]) * 100 * 4
# Error of missing data for PSH in Q4/2019
# Error of missing data for TNH in Q4/2019
# Error of missing data for TTA in Q4/2019
# Error of missing data for CKG in Q4/2019
# Error of missing data for ABS in Q4/2019
# ['TCH' 'TPB' 'MBB' 'DHC' 'DGW' 'VPI' 'D2D' 'BWE' 'PNJ' 'MBS' 'ITC' 'VHM'
#  'BID' 'HDB' 'GEG' 'PDR' 'KBC' 'KSB' 'PPC' 'MWG' 'QTP' 'TNG' 'VND' 'NLG'
#  'VGI' 'DCL' 'DRC' 'CII' 'DXG' 'VIB' 'VCS' 'AAA' 'CTG' 'TCM' 'HCM' 'CMG'
#  'TCD' 'TDC' 'HTN' 'HPG' 'HDG' 'TV2' 'VCI' 'FPT' 'VRE' 'ACB' 'IBC' 'IDC'
#  'CMX' 'VCG' 'SAB' 'VCB' 'BCM' 'PLX' 'VIC' 'LHG' 'MSN' 'VOS' 'CRE' 'SSI'
#  'BFC' 'BMP' 'PLC' 'HBC' 'HT1' 'VGC' 'FCN' 'TVS' 'ANV' 'NVL' 'DPR' 'BSR'
#  'VNM' 'CTD' 'KDH' 'GEX' 'CSV']
# Q2/2020
# Error of missing data for GVR in Q1/2020
# Error of missing data for THD in Q1/2020
# Error of missing data for OCB in Q1/2020
# Error of missing data for OIL in Q1/2020
# Error of missing data for ABB in Q1/2020
# Error of missing data for APH in Q1/2020
# Error of missing data for AGG in Q1/2020
# Error of missing data for PSH in Q1/2020
# Error of missing data for TNH in Q1/2020
# Error of missing data for TTA in Q1/2020
# Error of missing data for ABS in Q1/2020
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:163: RuntimeWarning: divide by zero encountered in double_scalars
#   res.append(current_ROE / previous_ROE - 1)
# ['DHC' 'GEG' 'VIB' 'VHM' 'DGW' 'TCD' 'SZC' 'TCH' 'D2D' 'IJC' 'HTN' 'BWE'
#  'HDG' 'CII' 'TPB' 'MIG' 'CTG' 'VCS' 'FPT' 'VGI' 'DRC' 'MWG' 'KDH' 'HPG'
#  'HCM' 'VCB' 'VIC' 'PHR' 'PDR' 'HDB' 'MBB' 'PPC' 'TNG' 'CMX' 'TV2' 'AAA'
#  'BMP' 'PC1' 'PNJ' 'HAH' 'ACB' 'LHG' 'VNM' 'FRT' 'KSB' 'FMC' 'CRE' 'SAB']
# Q3/2020
# Error of missing data for GVR in Q2/2020
# Error of missing data for THD in Q2/2020
# Error of missing data for OCB in Q2/2020
# Error of missing data for OIL in Q2/2020
# Error of missing data for ABB in Q2/2020
# Error of missing data for APH in Q2/2020
# Error of missing data for AGG in Q2/2020
# Error of missing data for PSH in Q2/2020
# Error of missing data for TNH in Q2/2020
# Error of missing data for TTA in Q2/2020
# Error of missing data for ABS in Q2/2020
# ['TCH' 'TPB' 'HDG' 'CTG' 'D2D' 'TVB' 'DGW' 'PDR' 'HDB' 'DHC' 'SZC' 'KDH'
#  'MBB' 'MSB' 'VIB' 'SSI' 'LHG' 'DPM' 'PHR' 'VCG' 'HHS' 'KSB' 'TVS' 'BID'
#  'DCL' 'TCM' 'MBS' 'MIG' 'GEG' 'VND' 'HCM' 'AAA' 'VCB' 'BMP' 'PLC' 'VHM'
#  'DCM' 'SAB' 'VCS' 'BMI' 'HPG' 'NVL' 'TCD' 'CRE' 'DRC' 'IJC' 'VJC' 'BWE'
#  'VCI' 'MWG' 'BFC' 'FPT' 'TNG' 'PPC' 'POW' 'VNM' 'NT2' 'CMX' 'TV2' 'PVT'
#  'ACB' 'GEX' 'CTD']
# Q4/2020
# Error of missing data for GVR in Q3/2020
# Error of missing data for THD in Q3/2020
# Error of missing data for OCB in Q3/2020
# Error of missing data for OIL in Q3/2020
# Error of missing data for ABB in Q3/2020
# Error of missing data for APH in Q3/2020
# Error of missing data for AGG in Q3/2020
# Error of missing data for PSH in Q3/2020
# Error of missing data for TNH in Q3/2020
# Error of missing data for TTA in Q3/2020
# Error of missing data for ABS in Q3/2020
# ['PDR' 'DGW' 'VIB' 'VPI' 'TCH' 'DHC' 'TCD' 'BWE' 'TDC' 'ACB' 'HPG' 'NVL'
#  'GEG' 'MSB' 'PLC' 'TPB' 'PC1' 'TV2' 'VGI' 'VHM' 'HTN' 'VND' 'TVB' 'MBS'
#  'VCG' 'TNG' 'AAA' 'VIC' 'VCS' 'KDH' 'HDB' 'SGP' 'KSB' 'D2D' 'BMI' 'MWG'
#  'CTG' 'CMX' 'TVS' 'HCM' 'DPR' 'G36' 'SMC' 'HDG' 'VNM' 'BVH' 'MBB' 'DRC'
#  'PNJ' 'BID' 'LTG' 'SZC' 'LHG' 'IJC' 'SAB' 'TCM' 'FMC' 'CMG' 'FPT' 'BMP'
#  'VGC' 'CRE' 'REE' 'DPM' 'PVT' 'BCM' 'GEX' 'VHC' 'SSI' 'VRE' 'MSH' 'VCB'
#  'HT1']
# Q1/2021
# Error of missing data for THD in Q4/2020
# Error of missing data for OCB in Q4/2020
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:165: RuntimeWarning: divide by zero encountered in double_scalars
#   revenue_growth_current_quarter = trailing_quarter.loc[(stock, current_quarter)]["sales"] / trailing_quarter.loc[(stock, last_current_quarter)]["sales"] - 1
# /home/trunght/workspace/stockPrediction/final_ver/analysis/CANSLIM_analysis.py:169: RuntimeWarning: divide by zero encountered in double_scalars
#   profit_growth_current_quarter = trailing_quarter.loc[(stock, current_quarter)]["netProfit"] / trailing_quarter.loc[(stock, last_current_quarter)]["netProfit"] - 1
# Error of missing data for AGG in Q4/2020
# Error of missing data for PSH in Q4/2020
# Error of missing data for TTA in Q4/2020
# ['MSB' 'DGW' 'ACB' 'HPG' 'PC1' 'IJC' 'SSI' 'TCD' 'VND' 'TVS' 'MIG' 'TVB'
#  'CTG' 'MBS' 'DHC' 'SMC' 'GEX' 'VIB' 'GEG' 'VHM' 'LTG' 'NKG' 'GVR' 'LHG'
#  'VCI' 'TNH' 'REE' 'ITC' 'EVS' 'G36' 'IBC' 'HAH' 'ABB' 'BVS' 'HCM' 'DCM'
#  'TV2' 'PDR' 'CSC' 'BVH' 'DRC' 'VCB' 'KDH' 'TCH' 'HTN' 'FTS' 'BMP' 'QTP'
#  'PVT' 'HDG' 'PHR' 'POW' 'FMC' 'SGP' 'DPR' 'VCS' 'TDC' 'CRE' 'SAB' 'TCM'
#  'VCG' 'VRE' 'MSN' 'CMX' 'BFC' 'BWE' 'D2D' 'PNJ' 'FPT' 'HDB' 'NLG' 'DCL'
#  'NVL' 'TPB']
# Q2/2021
# Error of missing data for THD in Q1/2021
# Error of missing data for OCB in Q1/2021
# Error of missing data for TTA in Q1/2021
# ['TVB' 'DHC' 'HPG' 'VND' 'DGW' 'SSI' 'CTG' 'VIB' 'TCD' 'HCM' 'MSB' 'MBS'
#  'TVN' 'VCI' 'GVR' 'MIG' 'SZC' 'NKG' 'HAH' 'KDH' 'GEX' 'ACB' 'DCM' 'DPR'
#  'BFC' 'DPM' 'SMC' 'HDB' 'TVS' 'IJC' 'HDG' 'DRC' 'VCB' 'TCM' 'KBC' 'SBT'
#  'TCH' 'TPB' 'VCG' 'AAA' 'CRE' 'TNH' 'MBB' 'NVL' 'REE' 'PDR' 'VHM' 'BVH'
#  'VRE' 'DXG' 'ABB' 'PLC' 'BID' 'EVS' 'PHR' 'PNJ' 'SGP' 'BWE' 'CMG' 'LTG'
#  'SAB' 'HTN' 'MSH' 'BVS' 'VGC' 'ANV' 'PVT' 'VCS' 'BMI' 'LHG' 'BCM' 'TNG'
#  'FMC' 'NLG' 'VGT' 'BMP' 'FPT' 'FTS' 'D2D' 'IDC' 'GEG' 'MWG' 'VHC' 'HT1'
#  'GAS' 'CSV']
# Q3/2021
# Error of missing data for THD in Q2/2021
# Error of missing data for OCB in Q2/2021
# Error of missing data for TTA in Q2/2021
# ['DHC' 'IJC' 'NKG' 'EVS' 'MIG' 'HPG' 'TCD' 'DPM' 'HTN' 'MSB' 'LHG' 'TVS'
#  'PC1' 'VND' 'TVB' 'SMC' 'ACB' 'DGW' 'TPB' 'SZC' 'ABB' 'TVN' 'PDR' 'VHM'
#  'VIB' 'GEX' 'HCM' 'MBS' 'AGG' 'DDV' 'DRC' 'BWE' 'DCL' 'PNJ' 'FTS' 'CMX'
#  'HAH' 'VCS' 'MSH' 'BMI' 'GMD' 'KDH' 'VGC' 'TDC' 'TNG' 'MSN' 'VCI' 'TNH'
#  'SSI' 'PLC' 'SBT' 'GVR' 'FMC' 'QTP' 'TV2' 'MWG' 'VGT' 'CMG' 'NVL' 'BCC'
#  'PLX' 'SGP' 'DCM' 'VIC' 'HDB' 'CRE' 'IDC' 'REE' 'GEG' 'VHC' 'PHR' 'BFC'
#  'BID' 'BVS' 'CTG' 'GAS' 'BVH' 'FPT' 'DXG' 'LTG' 'HT1' 'BCM' 'BMP' 'POM'
#  'D2D' 'MBB' 'CSV' 'TCM' 'BSR']
# Q4/2021
# Error of missing data for THD in Q3/2021
# Error of missing data for OCB in Q3/2021
# Error of missing data for TTA in Q3/2021
# ['SZC' 'SSI' 'DPM' 'EVS' 'TNH' 'DHC' 'HCM' 'MSB' 'IJC' 'VCI' 'TVB' 'SBT'
#  'VND' 'HPG' 'MIG' 'FTS' 'MBS' 'NKG' 'HAH' 'CSC' 'TCD' 'D2D' 'DGW' 'TVS'
#  'MSH' 'TV2' 'DCM' 'VHC' 'TPB' 'CMX' 'VHM' 'MBB' 'PC1' 'PHR' 'SMC' 'CTG'
#  'PDR' 'DDV' 'MSN' 'HDB' 'VGT' 'ACB' 'VCB' 'SGP' 'VIB' 'HDG' 'ABB' 'CRE'
#  'VCS' 'NLG' 'BFC' 'TNG' 'GMD' 'KDH' 'BWE' 'BVH' 'CMG' 'PSH' 'GVR' 'FPT'
#  'GAS' 'FMC' 'DPR' 'FRT' 'VOS']
# Q1/2022
# Error of missing data for TTA in Q4/2021
# ['TVB' 'DPM' 'SSI' 'SZC' 'DGW' 'VHC' 'SGP' 'DCM' 'VND' 'HDB' 'KDC' 'VGT'
#  'TNG' 'MBB' 'DXG' 'GMD' 'HPG' 'FRT' 'SGT' 'GEX' 'EVS' 'HAH' 'MSH' 'BID'
#  'NKG' 'BFC' 'CMG' 'HCM' 'PAN' 'VIB' 'VGC' 'MBS' 'BVS' 'CRE' 'VCI' 'FTS'
#  'CSV' 'MWG' 'NLG' 'PLX' 'HTN' 'PSH' 'BWE' 'TPB' 'MSN' 'NVL' 'DPR' 'TVS'
#  'FMC' 'PDR' 'FPT' 'GAS' 'REE' 'HDG' 'SBT' 'VPI' 'DRC' 'BSR' 'VOS' 'CSC'
#  'IJC' 'PNJ' 'DDV' 'DHC' 'MSB' 'PC1' 'TNH' 'VHM' 'GEG' 'TCD' 'LTG' 'BVH'
#  'TDC' 'VCS' 'ABB' 'NT2' 'IBC' 'VCB' 'OCB' 'MIG' 'D2D' 'SAB' 'KDH' 'AGG'
#  'TV2' 'BMP' 'GVR' 'VNM' 'ACB']
# Q2/2022
# ['DCM' 'GEX' 'VHC' 'PAN' 'MBS' 'DGW' 'IDI' 'VND' 'DPM' 'SSI' 'DDV' 'CSV'
#  'NKG' 'BFC' 'GAS' 'SGT' 'GEG' 'REE' 'FRT' 'VGT' 'GMD' 'IDC' 'FTS' 'VPI'
#  'TNG' 'HAH' 'HPG' 'BID' 'MSB' 'VCI' 'PNJ' 'HDB' 'VGC' 'ACB' 'LHG' 'FMC'
#  'ABB' 'PC1' 'MIG' 'MBB' 'SZC' 'ANV' 'PHR' 'CSC' 'VCG' 'FPT' 'VIB' 'PLC'
#  'CMG' 'DRC' 'MSH' 'QTP' 'TCD' 'CRE' 'MSN' 'SMC' 'BSR' 'HCM' 'BVS' 'NT2'
#  'TVB' 'OIL' 'TPB' 'LTG' 'SAB' 'SGP' 'DXG' 'HTN' 'BMP' 'BMI' 'CII' 'PDR'
#  'TCM' 'IJC' 'MWG' 'VCB' 'DHC' 'TVS' 'BWE' 'VOS' 'VHM' 'PVT' 'BVH' 'VCS'
#  'CTG' 'GVR' 'SBT' 'NVL' 'OCB' 'VGI' 'BCM' 'KSB']
# Q3/2022
# ['HDB' 'KDC' 'MBB' 'ABB' 'IDC' 'TPB' 'CMG' 'BID' 'ACB' 'HAH' 'VCB' 'DCM'
#  'DPM' 'PNJ' 'CSC' 'PDR' 'GAS' 'BSR' 'VPI' 'GMD' 'TNG' 'VHC' 'TCD' 'FRT'
#  'DPR' 'VGC' 'PAN' 'IJC' 'VGT' 'DGW' 'ANV' 'NT2' 'CMX' 'OIL' 'DDV' 'VND'
#  'IDI' 'CSV' 'EVS' 'FMC' 'HCM' 'TDC' 'VOS' 'CTG' 'REE' 'ITC' 'VIB' 'VCI'
#  'SSI' 'SAB' 'SZC' 'HDG' 'MBS' 'NKG' 'HPG' 'TNH' 'BCM' 'SMC' 'GEX' 'FPT'
#  'BFC' 'SGP' 'FTS' 'MSH' 'LHG' 'BMP' 'BMI' 'KDH' 'CRE' 'MSB' 'PLC' 'MSN'
#  'BWE' 'VGI' 'DHC' 'QTP' 'AGG' 'SBT' 'VCS' 'DRC' 'MWG' 'HTN' 'OCB' 'NVL']
# Q4/2022
# ['HDB' 'TPB' 'DGW' 'BID' 'IJC' 'VIB' 'FRT' 'CSV' 'DCM' 'LHG' 'ACB' 'IDI'
#  'GMD' 'REE' 'DPM' 'MSB' 'LTG' 'HAH' 'VHC' 'MBB' 'MIG' 'MWG' 'CMX' 'VCG'
#  'DCL' 'TDC' 'DRC' 'PAN' 'VHM' 'MSH' 'GEG' 'IDC' 'SAB' 'QTP' 'BWE' 'VCB'
#  'AGG' 'GAS' 'VRE' 'VGC' 'TNG' 'CSC' 'FPT' 'CMG' 'PVT' 'VGI' 'DPR' 'VPI'
#  'PNJ' 'CTG' 'PDR' 'ANV' 'OCB' 'DDV' 'MBS' 'FMC' 'HCM' 'SBT' 'KBC' 'VCI'
#  'TNH' 'HDG' 'VOS' 'PHR' 'BMP' 'DHC' 'NT2' 'MSN' 'TCM' 'VCS']
# Q1/2023
# Error of missing data for SBT in Q4/2022
# Error of missing data for CKG in Q4/2022
# ['VCB' 'BID' 'CTG' 'IDC' 'VRE' 'GAS' 'TCM' 'ACB' 'BMP' 'ANV' 'PVS' 'DCL'
#  'PLC' 'TNH' 'PLX' 'REE' 'PVT' 'PNJ' 'PAN' 'HAH' 'VHC' 'SAB' 'PHR' 'BMI'
#  'DCM' 'SJS' 'TPB' 'CSV' 'SZC' 'PC1' 'VOS' 'CSC' 'VIC' 'BSR' 'FPT' 'VIB'
#  'HDB' 'GMD' 'MBB' 'DPM' 'VGC' 'LHG' 'LTG' 'CMG' 'VHM' 'TNG' 'VPI' 'FRT'
#  'FTS' 'OCB' 'MSB' 'NLG' 'DRC' 'DGW' 'BWE']

# %% [markdown]
# - Utility: REE, NT2, POW, QTP, BWE
# - Domestic consumption: MSN, VNM, SAB, QNS, MWG, PNJ, DGW, FRT, VRE
# - IT: FPT, CMG
# - Oil: GAS, PVD, PVT
# - Dividend yield: VEA, DPM, DCM, QTP, NT2
# - Others: TLG, DGC, PVT
